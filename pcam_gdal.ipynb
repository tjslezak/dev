# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/tjslezak/dev/blob/master/pcam_gdal.ipynb)

# %%
import os, sys
import matplotlib.pyplot as plt
from osgeo import gdal

# %%
url = 'https://pds-imaging.jpl.nasa.gov/data/mer/opportunity/mer1po_0xxx/data/sol4771/edr/1p551744931effczp8p2533r1m1.img'
data = gdal.Open('/vsicurl/' + url)
img = data.ReadAsArray()

# %%
plt.imshow(img, cmap='binary')
